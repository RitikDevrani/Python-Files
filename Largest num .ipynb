# %%
num_1 = input("Enter First Number")
if num_1.isdigit() == True:
    num1 = int(num_1)
else:
    print("Enter only valid numeric values!")
    
num_2 = input("Enter Second Number")
if num_2.isdigit() == True:
    num2 = int(num_2)
else:
    print("Enter only valid numeric values!")
    
num_3 = input("Enter Third Number")
if num_3.isdigit() == True:
    num3 = int(num_3)
else:
    print("Enter only valid numeric values!")
    
if num1>num2 and num1>num3:
        print(num1,"is the largest")
elif num2>num1 and num2>num3:
        print(num2,"is the largest")
else:
        print(num3,"is the largest")
# Out:
# Enter First Number km
# Enter only valid numeric values!
# Enter Second Number hv
# Enter only valid numeric values!
# Enter Third Number dz
# Enter only valid numeric values!
# 69 is the largest

# %%
nums = input("Enter numbers").split()
numbers = []
strings = []
for item in nums:
    if isinstance(item,(int,float)):
        numbers.append(item)
    else:
        strings.append(item)
print("The largest number is :",max(numbers))
# Out:
# Enter numbers 45 85 dfd dff    65 98 75
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 10
#       8     else:
#       9         strings.append(item)
# ---> 10 print("The largest number is :",max(numbers))
#
# ValueError: max() iterable argument is empty

# %%
print(nums)
# Out:
# ['4', '5', ' ', '8', '4', '5', ' ', 'e', 'f', ' ', 'd', 'o', ' ', 'o', ' ', ' ', ' ', '8', '5', ' ', '2', ' ', '9', '5', ' ', '7', '5', ' ', '2', '6', ' ', '8', ' ']

# %%
print(numbers)
print(strings)
print(snums)
# Out:
# []
# ['45', '85', 'dfd', 'dff', '65', '98', '75']
# ['45', '85', 'dfd', 'dff', '65', '98', '75']

# %% [markdown]
# # Print function:
# - Definition: Used to display output on the screen.

# %%
print("Data Analyst")
# Out:
# Data Analyst

# %%
8+6
# Out:
# 14

# %%
8*9/3
# Out:
# 24.0

# %%
print(9/3)
# Out:
# 3.0

# %%
"Hello Everyone, Good Morning"
# Out:
# 'Hello Everyone, Good Morning'

# %% [markdown]
# # Comment
# - Comments are used to write something which the programmer does not want to excute. Comments can be used to mark the author's name data etc.

# %%
print("Learning Python") #Learning python Language
# Out:
# Learning Python

# %%
print(6+5) # This program will give sum of these two number
# Out:
# 11

# %% [markdown]
# # Docstring
# - Its use is to provide explanation of the code, so that other programmer can easly understand what the code does.

# %%
print("Python is a High Level general purpose programming language")
"""Learning Python"""
# Out:
# Python is a High Level general purpose programming language
# 'Learning Python'

# %% [markdown]
# # Variables
# - A variable in Python is a symbolic name that is a reference or pointer to an object. In simple terms, variables are like containers that hold different types of data values. Once a variable is assigned a value, you can use that variable in place of the value.
#   - we assign values to variables using the assignment operator(=).
#   - variable_name = value
#   - greeting = "Hello World"
#   - print(greeting)

# %%
Name = "IIDI" # Create a variable & store a Object
Name
# Out:
# 'IIDI'

# %%
Number = 79
Number_2 = 45
print(Number + Number_2)
# Out:
# 124

# %%
MyName = "Ritik"    # Pascal Case
myName = "Ritik"    # Camel Case
myname = "Ritik"    # Flate Case
_my_name = "Ritik"  # Snack Case

# %%
a,b,c = 8,5,9 #multiple variable create a single line

# %%
a
# Out:
# 8

# %%
a+b+c
# Out:
# 22

# %% [markdown]
# # Rules Of Variable In Python
# - A variable name must start with an Alphabet or an underscore.
# - A variable name cannot start with a number or any special character(@,#,$,%,).
# - A variable name can only contain alphabets, numbers and underscores.
# - Variables names are case sensitive in Python.
# - Python keywords cannot be used as variables name.

# %%
 Name = "Data Science"  # First Rule of Variable

# %%
_233 = 67

# %%
99 = 87 # Second Rule of Variable

# %%
My_Name_13 = "Ritik"  # Third Rule of variable

# %%
Student = "Ritik"  # Fourth Rule of variable
#  print(student) Wrong
# print(Student) right
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 Student = "Ritik"
# ----> 2 Print(student)
#
# NameError: name 'Print' is not defined

# %%
# Fifth Rule of Variable
# for = 23
# while = "Ritik"

# %% [markdown]
# # Keywords
# - In Python, Keywords are reserved words that have a special meaning in the programming language. You cannot use them as names for variables, functions, or identifiers.
#   - Key Points about Python Keywords:
#      - Python keywords are case-sensitive.
#      - Example: if is valid, but IF is not.
#      - They define the syntax and structure of the language.
#      - Python has around 35 keywords.

# %%
help("keywords") # help function to get the keywords
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
If = 35 #right
if = 34 #wrong
in = "hello"
IN = "hello"

# %% [markdown]
# # What is a Statement in Python ?
# - A statement is an instrution that a python interpreter can execute. So, in simple words, we can say anything written in python is a statement.
# - In Python, we can add Multiple statements on a single line seprated by semicolon, as follow:
#    - TWO STATEMENT IN A SINGLE LINE:
#       - l=2; b=6
#       - print("area of rectangle:"l*b)

# %%
Name = "Data"; Last_Name = "Analyst"     
Name+Last_Name      #Concatenate (Merging Strings)
# Out:
# 'DataAnalyst'

# %%
num1 = 5; num2 = 10; num3 = 15
num1*num3+num2
# Out:
# 85
